# %%
# %reset -f
import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.axes import Axes
from matplotlib import gridspec
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,AutoMinorLocator)
from matplotlib.ticker import NullFormatter
from IPython.display import set_matplotlib_formats
#User-defined package
import general as g

# %matplotlib inline
#有了%matplotlib inline 就可以省掉plt.show()了
set_matplotlib_formats('svg')
#svg: Scalable Vector Graphics
# Out:
# /var/folders/p4/k2mn1bys7kj2_sc0401cf08h0000gn/T/ipykernel_32566/78877899.py:16: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('svg')

# %%
def pl_delchi(infile,mycolor='red'):
        g.rewrite_ipl(infile)
        fig = plt.figure(figsize=(10,2.5))

        datafile = f"temp-0.txt"
        data = np.genfromtxt(datafile, unpack=True)

        ax = plt.subplot(1,1,1)
        ax.set_xscale('log')
        ax.errorbar(x=data[0],y=data[2],xerr=data[1],yerr=data[3],marker='o',ms=0.0,color=mycolor,fmt='o')
        
        #delete temp files
        temp_file = g.rewrite_ipl(infile)
        for n in range(temp_file):
                os.remove(f"temp-{n}.txt")
                if os.path.exists(f"temp-{n}.txt-e") is True:
                        os.remove(f"temp-{n}.txt-e")

infile='relionCp-nk_half-br_pl-delchi.txt'
pl_delchi(infile,'green')
# Out:
# /var/folders/p4/k2mn1bys7kj2_sc0401cf08h0000gn/T/ipykernel_32566/611960219.py:10: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   ax.errorbar(x=data[0],y=data[2],xerr=data[1],yerr=data[3],marker='o',ms=0.0,color=mycolor,fmt='o')

# %%
def do_pl_delchi(infile,ax,mycolor='red'):
        g.rewrite_ipl(infile)
        
        datafile = f"temp-0.txt"
        data = np.genfromtxt(datafile, unpack=True)
             
        ax.set_xscale('log')
        ax.errorbar(x=data[0],y=data[2],xerr=data[1],yerr=data[3],marker='o',ms=0.0,color=mycolor,fmt='o')
        
        #delete temp files
        temp_file = g.rewrite_ipl(infile)
        for n in range(temp_file):
                os.remove(f"temp-{n}.txt")
                if os.path.exists(f"temp-{n}.txt-e") is True:
                        os.remove(f"temp-{n}.txt-e")

# %%
def pl_delchi_2files(infiles:list):
        colors=['red','green']
        fig = plt.figure(figsize=(30,10))
        ax = plt.subplot(1,1,1)
        
        do_pl_delchi(infiles[0],ax,mycolor=colors[0])
        do_pl_delchi(infiles[1],ax,mycolor=colors[1])
        # plt.legend()

pl_delchi_2files(['relionCp-nk_half-br_pl-delchi.txt','relionCp-nk_pl-delchi.txt'])
# Out:
# /var/folders/p4/k2mn1bys7kj2_sc0401cf08h0000gn/T/ipykernel_32566/1848505483.py:8: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   ax.errorbar(x=data[0],y=data[2],xerr=data[1],yerr=data[3],marker='o',ms=0.0,color=mycolor,fmt='o')
# /var/folders/p4/k2mn1bys7kj2_sc0401cf08h0000gn/T/ipykernel_32566/1848505483.py:8: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   ax.errorbar(x=data[0],y=data[2],xerr=data[1],yerr=data[3],marker='o',ms=0.0,color=mycolor,fmt='o')
